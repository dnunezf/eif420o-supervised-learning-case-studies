# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from prince import PCA as PCA_Prince
from sklearn.decomposition import PCA
from sklearn.datasets import load_digits
from sklearn.preprocessing import StandardScaler

# %%
import ModuloACP

# %%
df = pd.read_csv("/home/dnunezf/Documents/AI_LABS/Lab_05-03-2026/titanic_sample.csv",delimiter=',',decimal=".",index_col=0)

# %%
df
# Out:
#            Age   Fare  SibSp  Parch  Pclass
# Passenger
# P1          22   7.25      1      0       3
# P2          38  71.28      1      0       1
# P3          26   7.92      0      0       3
# P4          35  53.10      1      0       1
# P5          30   8.05      0      0       3
# P6          54  51.86      0      0       1
# P7          27  11.13      0      2       3
# P8          14  30.07      1      0       2

# %%
# Declara la instancia de clase
acp = ModuloACP.ACP(df,n_componentes=2)
# Despliega las Componenentes Principales (llamado por el profesor 'Inercia de Datos, que reduce a 2 columnas')
print('correlaciones usadas en el círculo (la de los componentes\n):', acp.correlacion_var)
# Out:
# correlaciones usadas en el círculo (la de los componentes
# ): component         0         1
# variable
# Age        0.640005  0.722802
# Fare       0.961685  0.062778
# SibSp      0.458362 -0.825058
# Parch     -0.508175  0.433630
# Pclass    -0.974289 -0.077559

# %%
# Plotea el plano principal
fig, ax = plt.subplots(nrows=1, ncols=1, figsize = (10,6), dpi = 200)
acp.plot_plano_principal()
plt.show()

# %%
# Plotea el círculo de correlación
fig, ax = plt.subplots(nrows=1, ncols=1, figsize = (10,6), dpi = 200)
acp.plot_circulo()
plt.show()
print('correlaciones de todas las variables sin reducción dimensional:\n',df.corr())
# Out:
# correlaciones de todas las variables sin reducción dimensional:
#               Age      Fare     SibSp     Parch    Pclass
# Age     1.000000  0.605207 -0.312192 -0.126426 -0.634447
# Fare    0.605207  1.000000  0.433274 -0.300092 -0.971438
# SibSp  -0.312192  0.433274  1.000000 -0.377964 -0.404520
# Parch  -0.126426 -0.300092 -0.377964  1.000000  0.356753
# Pclass -0.634447 -0.971438 -0.404520  0.356753  1.000000

# %%
# Plotea el círculo de correlación
fig, ax = plt.subplots(nrows=1, ncols=1, figsize = (10,6), dpi = 200)
acp.plot_sobreposicion()
plt.show()
