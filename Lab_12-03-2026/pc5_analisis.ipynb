# %%
#Importamos las bibliotecas necesarias
import os
import numpy as np
import pandas as pd
from math import pi
import seaborn as sns
import No_Supervisados as ns
import matplotlib.pyplot as plt
from scipy.spatial.distance import pdist
from scipy.cluster.hierarchy import dendrogram, ward, single, complete,average,linkage, fcluster
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

pd.options.display.max_rows = 10

# %%
import No_Supervisados

# %%
# Opción a
path = "/home/dnunezf/Documents/AI_LABS/Lab_12-03-2026/PC5.csv"
df = pd.read_csv(path,delimiter=',',decimal=".", index_col=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17001 entries, 1 to 17001
# Data columns (total 39 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   LOC_BLANK                        17001 non-null  int64
#  1   BRANCH_COUNT                     17001 non-null  int64
#  2   CALL_PAIRS                       17001 non-null  int64
#  3   LOC_CODE_AND_COMMENT             17001 non-null  int64
#  4   LOC_COMMENTS                     17001 non-null  int64
#  5   CONDITION_COUNT                  17001 non-null  int64
#  6   CYCLOMATIC_COMPLEXITY            17001 non-null  int64
#  7   CYCLOMATIC_DENSITY               17001 non-null  float64
#  8   DECISION_COUNT                   17001 non-null  int64
#  9   DESIGN_COMPLEXITY                17001 non-null  int64
#  10  DESIGN_DENSITY                   17001 non-null  float64
#  11  EDGE_COUNT                       17001 non-null  int64
#  12  ESSENTIAL_COMPLEXITY             17001 non-null  int64
#  13  ESSENTIAL_DENSITY                17001 non-null  float64
#  14  LOC_EXECUTABLE                   17001 non-null  int64
#  15  PARAMETER_COUNT                  17001 non-null  int64
#  16  GLOBAL_DATA_COMPLEXITY           17001 non-null  int64
#  17  GLOBAL_DATA_DENSITY              17001 non-null  float64
#  18  HALSTEAD_CONTENT                 17001 non-null  float64
#  19  HALSTEAD_DIFFICULTY              17001 non-null  float64
#  20  HALSTEAD_EFFORT                  17001 non-null  float64
#  21  HALSTEAD_ERROR_EST               17001 non-null  float64
#  22  HALSTEAD_LENGTH                  17001 non-null  int64
#  23  HALSTEAD_LEVEL                   17001 non-null  float64
#  24  HALSTEAD_PROG_TIME               17001 non-null  float64
#  25  HALSTEAD_VOLUME                  17001 non-null  float64
#  26  MAINTENANCE_SEVERITY             17001 non-null  float64
#  27  MODIFIED_CONDITION_COUNT         17001 non-null  int64
#  28  MULTIPLE_CONDITION_COUNT         17001 non-null  int64
#  29  NODE_COUNT                       17001 non-null  int64
#  30  NORMALIZED_CYLOMATIC_COMPLEXITY  17001 non-null  float64
#  31  NUM_OPERANDS                     17001 non-null  int64
#  32  NUM_OPERATORS                    17001 non-null  int64
#  33  NUM_UNIQUE_OPERANDS              17001 non-null  int64
#  34  NUM_UNIQUE_OPERATORS             17001 non-null  int64
#  35  NUMBER_OF_LINES                  17001 non-null  int64
#  36  PERCENT_COMMENTS                 17001 non-null  float64
#  37  LOC_TOTAL                        17001 non-null  int64
#  38  Defective                        17001 non-null  object
# dtypes: float64(14), int64(24), object(1)
# memory usage: 5.2+ MB

# %%
df.shape
# Out:
# (17001, 39)

# %%
df.dtypes
# Out:
# LOC_BLANK                 int64
# BRANCH_COUNT              int64
# CALL_PAIRS                int64
# LOC_CODE_AND_COMMENT      int64
# LOC_COMMENTS              int64
#                          ...
# NUM_UNIQUE_OPERATORS      int64
# NUMBER_OF_LINES           int64
# PERCENT_COMMENTS        float64
# LOC_TOTAL                 int64
# Defective                object
# Length: 39, dtype: object

# %%
df.head()
# Out:
#     LOC_BLANK  BRANCH_COUNT  CALL_PAIRS  LOC_CODE_AND_COMMENT  LOC_COMMENTS  \
# id
# 1           0             1           0                     0             0
# 2           8             5           9                     0             6
# 3           3             1           4                     0             3
# 4           0             1           1                     0             0
# 5           3            25           0                    18             9
#
#     CONDITION_COUNT  CYCLOMATIC_COMPLEXITY  CYCLOMATIC_DENSITY  \
# id
# 1                 0                      1                1.00
# 2                 8                      3                0.19
# 3                 0                      1                0.17
# 4                 0                      1                0.33
# 5                40                     13                0.19
#
#     DECISION_COUNT  DESIGN_COMPLEXITY  ...  NODE_COUNT  \
# id                                     ...
# 1                0                  1  ...           2
# 2                4                  1  ...          24
# 3                0                  1  ...           6
# 4                0                  1  ...           3
# 5               16                  1  ...          32
#
#     NORMALIZED_CYLOMATIC_COMPLEXITY  NUM_OPERANDS  NUM_OPERATORS  \
# id
# 1                              1.00             0              1
# 2                              0.09            33             58
# 3                              0.07            11             18
# 4                              0.14             4              9
# 5                              0.15           108            134
#
#     NUM_UNIQUE_OPERANDS  NUM_UNIQUE_OPERATORS  NUMBER_OF_LINES  \
# id
# 1                     0                     1                1
# 2                    14                    14               34
# 3                     7                     9               15
# 4                     4                     8                7
# 5                    18                    19               86
#
#     PERCENT_COMMENTS  LOC_TOTAL  Defective
# id
# 1               0.00          0          N
# 2              27.27         16          N
# 3              33.33          6          N
# 4               0.00          3          N
# 5              35.06         68          N
#
# [5 rows x 39 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import StandardScaler

# ===============================
# 1. Cargar dataset
# ===============================

X = df.drop("Defective", axis=1)
y = df["Defective"]

# ===============================
# 2. Escalar variables
# ===============================

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# ===============================
# 3. Train / Test split
# ===============================

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y,
    test_size=0.3,
    random_state=42,
    stratify=y
)

# ===============================
# 4. Logistic Regression (None)
# ===============================

lr_none = LogisticRegression(
    max_iter=1000,
    class_weight=None
)

lr_none.fit(X_train, y_train)

proba_none = lr_none.predict_proba(X_test)[:,1]

auc_none = roc_auc_score(y_test, proba_none)

# ===============================
# 5. Logistic Regression (Balanced)
# ===============================

lr_balanced = LogisticRegression(
    max_iter=1000,
    class_weight='balanced'
)

lr_balanced.fit(X_train, y_train)

proba_balanced = lr_balanced.predict_proba(X_test)[:,1]

auc_balanced = roc_auc_score(y_test, proba_balanced)

# ===============================
# 6. Benchmark
# ===============================

results = pd.DataFrame({
    "Model": ["Logistic Regression (None)", "Logistic Regression (Balanced)"],
    "AUC": [auc_none, auc_balanced]
})

print(results)
# Out:
#                             Model       AUC
# 0      Logistic Regression (None)  0.950934
# 1  Logistic Regression (Balanced)  0.944701
